# %% [markdown]
# # SQL practice questions

# %% [markdown]
# ## import data from csv to sql

# %%
import sqlite3
import pandas as pd
# create database
connection = sqlite3.connect('db')
df = pd.read_csv(r'C:\Users\Divya\Downloads\ds_salaries.csv')
df.to_sql('salary', connection, if_exists='replace', index=False)
# connect cursor
cursor = connection.cursor()
cursor.execute("SELECT * FROM salary")
rows = cursor.fetchall()[:6]
for row in rows:
    print(row)
# Out:
# (2023, 'SE', 'FT', 'Principal Data Scientist', 80000, 'EUR', 85847, 'ES', 100, 'ES', 'L')
# (2023, 'MI', 'CT', 'ML Engineer', 30000, 'USD', 30000, 'US', 100, 'US', 'S')
# (2023, 'MI', 'CT', 'ML Engineer', 25500, 'USD', 25500, 'US', 100, 'US', 'S')
# (2023, 'SE', 'FT', 'Data Scientist', 175000, 'USD', 175000, 'CA', 100, 'CA', 'M')
# (2023, 'SE', 'FT', 'Data Scientist', 120000, 'USD', 120000, 'CA', 100, 'CA', 'M')
# (2023, 'SE', 'FT', 'Applied Scientist', 222200, 'USD', 222200, 'US', 0, 'US', 'L')

# %%
cursor.execute("PRAGMA table_info(salary)")

# %% [markdown]
# ## Basic SELECT Queries

# %% [markdown]
# 1. Fetch all records from the table.

# %%
query="SELECT * FROM salary"
data=pd.read_sql_query(query,connection)
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# 2. Retrieve only the job_title and salary_in_usd columns.

# %%
cursor.execute("SELECT job_title, salary_in_usd FROM salary")
cursor.fetchall()[:10]
# Out:
# [('Principal Data Scientist', 85847),
#  ('ML Engineer', 30000),
#  ('ML Engineer', 25500),
#  ('Data Scientist', 175000),
#  ('Data Scientist', 120000),
#  ('Applied Scientist', 222200),
#  ('Applied Scientist', 136000),
#  ('Data Scientist', 219000),
#  ('Data Scientist', 141000),
#  ('Data Scientist', 147100)]

# %% [markdown]
# 3. Show distinct job_title values in the dataset.

# %%
cursor.execute("SELECT DISTINCT job_title FROM salary")
cursor.fetchall()[:10]
# Out:
# [('Principal Data Scientist',),
#  ('ML Engineer',),
#  ('Data Scientist',),
#  ('Applied Scientist',),
#  ('Data Analyst',),
#  ('Data Modeler',),
#  ('Research Engineer',),
#  ('Analytics Engineer',),
#  ('Business Intelligence Engineer',),
#  ('Machine Learning Engineer',)]

# %% [markdown]
# 4. Display all columns for employees with a remote_ratio of 50.

# %%
query="SELECT * FROM salary WHERE remote_ratio = 50"
data=pd.read_sql_query(query,connection)
data
# Out:
#      work_year experience_level employment_type  \
# 0         2022               MI              FT
# 1         2022               EN              FT
# 2         2023               EN              FT
# 3         2023               MI              FT
# 4         2023               SE              FT
# ..         ...              ...             ...
# 184       2020               MI              FT
# 185       2021               MI              FT
# 186       2021               MI              FT
# 187       2021               MI              FT
# 188       2021               SE              FT
#
#                               job_title   salary salary_currency  \
# 0             Machine Learning Engineer  1650000             INR
# 1                          AI Developer   300000             USD
# 2                    Research Scientist   220000             USD
# 3                 Business Data Analyst   105000             USD
# 4                  Data DevOps Engineer    50000             EUR
# ..                                  ...      ...             ...
# 184                      Data Scientist    55000             EUR
# 185                      Data Scientist   115000             USD
# 186  Applied Machine Learning Scientist   423000             USD
# 187                       Data Engineer    24000             EUR
# 188                Data Science Manager  7000000             INR
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 0            20984                 IN            50               IN
# 1           300000                 IN            50               IN
# 2           220000                 US            50               US
# 3           105000                 US            50               US
# 4            53654                 FR            50               FR
# ..             ...                ...           ...              ...
# 184          62726                 FR            50               LU
# 185         115000                 US            50               US
# 186         423000                 US            50               US
# 187          28369                 MT            50               MT
# 188          94665                 IN            50               IN
#
#     company_size
# 0              L
# 1              L
# 2              L
# 3              L
# 4              S
# ..           ...
# 184            S
# 185            L
# 186            L
# 187            L
# 188            L
#
# [189 rows x 11 columns]

# %% [markdown]
# 5. Select all records where the company_location is different
# from the employee_residence.

# %%
query = "SELECT * FROM salary WHERE company_location != employee_residence"
different_locations = pd.read_sql_query(query, connection)
different_locations
# Out:
#     work_year experience_level employment_type  \
# 0        2023               SE              FT
# 1        2023               MI              FT
# 2        2020               EX              FT
# 3        2023               SE              FT
# 4        2022               SE              FT
# ..        ...              ...             ...
# 91       2021               EN              FT
# 92       2020               MI              FT
# 93       2021               EN              PT
# 94       2020               MI              FT
# 95       2021               MI              FT
#
#                             job_title   salary salary_currency  salary_in_usd  \
# 0           Machine Learning Engineer   150000             USD         150000
# 1   Applied Machine Learning Engineer    65000             EUR          69751
# 2                  Staff Data Analyst    15000             USD          15000
# 3              Applied Data Scientist   100000             AUD          68318
# 4                      Data Scientist    84000             EUR          88256
# ..                                ...      ...             ...            ...
# 91                       AI Scientist  1335000             INR          18053
# 92                     Data Scientist    55000             EUR          62726
# 93                       AI Scientist    12000             USD          12000
# 94                      Data Engineer   130800             USD         130800
# 95                     Data Scientist   160000             SGD         119059
#
#    employee_residence  remote_ratio company_location company_size
# 0                  PT           100               US            M
# 1                  IN           100               DE            S
# 2                  NG             0               CA            M
# 3                  AU           100               FI            M
# 4                  ES           100               GB            L
# ..                ...           ...              ...          ...
# 91                 IN           100               AS            S
# 92                 FR            50               LU            S
# 93                 BR           100               US            S
# 94                 ES           100               US            M
# 95                 SG           100               IL            M
#
# [96 rows x 11 columns]

# %% [markdown]
# ## Filtering with WHERE

# %% [markdown]
# 6. Find employees with a salary greater than 100,000 USD.

# %%
query = "SELECT * FROM salary WHERE salary_in_usd > 100000"
high_salary = pd.read_sql_query(query, connection)
high_salary
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               SE              FT
# 2          2023               SE              FT
# 3          2023               SE              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 2660       2021               MI              FT
# 2661       2021               SE              FT
# 2662       2020               SE              FT
# 2663       2021               MI              FT
# 2664       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 0                         Data Scientist  175000             USD
# 1                         Data Scientist  120000             USD
# 2                      Applied Scientist  222200             USD
# 3                      Applied Scientist  136000             USD
# 4                         Data Scientist  219000             USD
# ...                                  ...     ...             ...
# 2660  Applied Machine Learning Scientist  423000             USD
# 2661                     Data Specialist  165000             USD
# 2662                      Data Scientist  412000             USD
# 2663            Principal Data Scientist  151000             USD
# 2664                      Data Scientist  105000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0            175000                 CA           100               CA
# 1            120000                 CA           100               CA
# 2            222200                 US             0               US
# 3            136000                 US             0               US
# 4            219000                 CA             0               CA
# ...             ...                ...           ...              ...
# 2660         423000                 US            50               US
# 2661         165000                 US           100               US
# 2662         412000                 US           100               US
# 2663         151000                 US           100               US
# 2664         105000                 US           100               US
#
#      company_size
# 0               M
# 1               M
# 2               L
# 3               L
# 4               M
# ...           ...
# 2660            L
# 2661            L
# 2662            L
# 2663            L
# 2664            S
#
# [2665 rows x 11 columns]

# %% [markdown]
# 7. Retrieve all records for employees in the US
# (employee_residence = 'US').

# %%
query = "SELECT * FROM salary WHERE employee_residence = 'US'"
us_employees = pd.read_sql_query(query, connection)
us_employees
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              CT               ML Engineer
# 1          2023               MI              CT               ML Engineer
# 2          2023               SE              FT         Applied Scientist
# 3          2023               SE              FT         Applied Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 2999       2021               SE              FT           Data Specialist
# 3000       2020               SE              FT            Data Scientist
# 3001       2021               MI              FT  Principal Data Scientist
# 3002       2020               EN              FT            Data Scientist
# 3003       2020               EN              CT     Business Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      30000             USD          30000                 US           100
# 1      25500             USD          25500                 US           100
# 2     222200             USD         222200                 US             0
# 3     136000             USD         136000                 US             0
# 4     147100             USD         147100                 US             0
# ...      ...             ...            ...                ...           ...
# 2999  165000             USD         165000                 US           100
# 3000  412000             USD         412000                 US           100
# 3001  151000             USD         151000                 US           100
# 3002  105000             USD         105000                 US           100
# 3003  100000             USD         100000                 US           100
#
#      company_location company_size
# 0                  US            S
# 1                  US            S
# 2                  US            L
# 3                  US            L
# 4                  US            M
# ...               ...          ...
# 2999               US            L
# 3000               US            L
# 3001               US            L
# 3002               US            S
# 3003               US            L
#
# [3004 rows x 11 columns]

# %% [markdown]
# 8. Find data for employees who work in large-sized companies
# (company_size = 'L').

# %%
query = "SELECT * FROM salary WHERE company_size = 'L'"
large_sized_companies = pd.read_sql_query(query, connection)
large_sized_companies
# Out:
#      work_year experience_level employment_type                 job_title  \
# 0         2023               SE              FT  Principal Data Scientist
# 1         2023               SE              FT         Applied Scientist
# 2         2023               SE              FT         Applied Scientist
# 3         2023               EN              FT         Applied Scientist
# 4         2023               EN              FT         Applied Scientist
# ..         ...              ...             ...                       ...
# 449       2021               SE              FT           Data Specialist
# 450       2020               SE              FT            Data Scientist
# 451       2021               MI              FT  Principal Data Scientist
# 452       2020               EN              CT     Business Data Analyst
# 453       2021               SE              FT      Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      80000             EUR          85847                 ES           100
# 1     222200             USD         222200                 US             0
# 2     136000             USD         136000                 US             0
# 3     213660             USD         213660                 US             0
# 4     130760             USD         130760                 US             0
# ..       ...             ...            ...                ...           ...
# 449   165000             USD         165000                 US           100
# 450   412000             USD         412000                 US           100
# 451   151000             USD         151000                 US           100
# 452   100000             USD         100000                 US           100
# 453  7000000             INR          94665                 IN            50
#
#     company_location company_size
# 0                 ES            L
# 1                 US            L
# 2                 US            L
# 3                 US            L
# 4                 US            L
# ..               ...          ...
# 449               US            L
# 450               US            L
# 451               US            L
# 452               US            L
# 453               IN            L
#
# [454 rows x 11 columns]

# %% [markdown]
# 9. Fetch records for employees who have remote_ratio = 100.

# %%
query="SELECT * FROM salary WHERE remote_ratio = 100"
data=pd.read_sql_query(query,connection)
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 1638       2021               SE              FT           Data Specialist
# 1639       2020               SE              FT            Data Scientist
# 1640       2021               MI              FT  Principal Data Scientist
# 1641       2020               EN              FT            Data Scientist
# 1642       2020               EN              CT     Business Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      80000             EUR          85847                 ES           100
# 1      30000             USD          30000                 US           100
# 2      25500             USD          25500                 US           100
# 3     175000             USD         175000                 CA           100
# 4     120000             USD         120000                 CA           100
# ...      ...             ...            ...                ...           ...
# 1638  165000             USD         165000                 US           100
# 1639  412000             USD         412000                 US           100
# 1640  151000             USD         151000                 US           100
# 1641  105000             USD         105000                 US           100
# 1642  100000             USD         100000                 US           100
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 1638               US            L
# 1639               US            L
# 1640               US            L
# 1641               US            S
# 1642               US            L
#
# [1643 rows x 11 columns]

# %% [markdown]
# 10. List all employees whose salary_in_usd is between
# 50,000 and 100,000

# %%
query = "SELECT * FROM salary WHERE salary_in_usd BETWEEN 50000 AND 100000"
employees = pd.read_sql_query(query, connection)
employees
# Out:
#      work_year experience_level employment_type                 job_title  \
# 0         2023               SE              FT  Principal Data Scientist
# 1         2023               SE              FT            Data Scientist
# 2         2023               SE              FT              Data Analyst
# 3         2023               SE              FT              Data Modeler
# 4         2023               SE              FT           Data Strategist
# ..         ...              ...             ...                       ...
# 821       2021               MI              FT              Data Analyst
# 822       2021               MI              FT              Data Analyst
# 823       2021               MI              FT            Data Scientist
# 824       2020               EN              CT     Business Data Analyst
# 825       2021               SE              FT      Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      80000             EUR          85847                 ES           100
# 1      90700             USD          90700                 US             0
# 2     100000             USD         100000                 US           100
# 3      90700             USD          90700                 US             0
# 4      90000             USD          90000                 CA             0
# ..       ...             ...            ...                ...           ...
# 821    75000             USD          75000                 US             0
# 822    62000             USD          62000                 US             0
# 823    73000             USD          73000                 US             0
# 824   100000             USD         100000                 US           100
# 825  7000000             INR          94665                 IN            50
#
#     company_location company_size
# 0                 ES            L
# 1                 US            M
# 2                 US            M
# 3                 US            M
# 4                 CA            M
# ..               ...          ...
# 821               US            L
# 822               US            L
# 823               US            L
# 824               US            L
# 825               IN            L
#
# [826 rows x 11 columns]

# %% [markdown]
# 11. Retrieve records where the job_title contains "Data
# Scientist".

# %%
query = "SELECT * FROM salary WHERE job_title LIKE '%Data Scientist%'"
records = pd.read_sql_query(query, connection)
records
# Out:
#      work_year experience_level employment_type                 job_title  \
# 0         2023               SE              FT  Principal Data Scientist
# 1         2023               SE              FT            Data Scientist
# 2         2023               SE              FT            Data Scientist
# 3         2023               SE              FT            Data Scientist
# 4         2023               SE              FT            Data Scientist
# ..         ...              ...             ...                       ...
# 866       2020               MI              FT            Data Scientist
# 867       2021               MI              FT            Data Scientist
# 868       2020               SE              FT            Data Scientist
# 869       2021               MI              FT  Principal Data Scientist
# 870       2020               EN              FT            Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     80000             EUR          85847                 ES           100
# 1    175000             USD         175000                 CA           100
# 2    120000             USD         120000                 CA           100
# 3    219000             USD         219000                 CA             0
# 4    141000             USD         141000                 CA             0
# ..      ...             ...            ...                ...           ...
# 866  138350             USD         138350                 US           100
# 867  160000             SGD         119059                 SG           100
# 868  412000             USD         412000                 US           100
# 869  151000             USD         151000                 US           100
# 870  105000             USD         105000                 US           100
#
#     company_location company_size
# 0                 ES            L
# 1                 CA            M
# 2                 CA            M
# 3                 CA            M
# 4                 CA            M
# ..               ...          ...
# 866               US            M
# 867               IL            M
# 868               US            L
# 869               US            L
# 870               US            S
#
# [871 rows x 11 columns]

# %% [markdown]
# 12. Find employees whose experience_level is either
# SE or MI.

# %%
query = "SELECT * FROM salary WHERE experience_level IN ('SE', 'MI')"
experience = pd.read_sql_query(query, connection)
experience
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3316       2021               MI              FT             Data Engineer
# 3317       2021               SE              FT           Data Specialist
# 3318       2020               SE              FT            Data Scientist
# 3319       2021               MI              FT  Principal Data Scientist
# 3320       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3316    24000             EUR          28369                 MT            50
# 3317   165000             USD         165000                 US           100
# 3318   412000             USD         412000                 US           100
# 3319   151000             USD         151000                 US           100
# 3320  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3316               MT            L
# 3317               US            L
# 3318               US            L
# 3319               US            L
# 3320               IN            L
#
# [3321 rows x 11 columns]

# %% [markdown]
# 13. Show all records for employees who joined in 2023.

# %%
query = "SELECT * FROM salary WHERE work_year = 2023"
work_year = pd.read_sql_query(query, connection)
work_year
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1780       2023               SE              FT  Machine Learning Engineer
# 1781       2023               MI              FT             Data Scientist
# 1782       2023               MI              FT             Data Scientist
# 1783       2023               EN              FT              Data Engineer
# 1784       2023               EN              FT              Data Engineer
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      80000             EUR          85847                 ES           100
# 1      30000             USD          30000                 US           100
# 2      25500             USD          25500                 US           100
# 3     175000             USD         175000                 CA           100
# 4     120000             USD         120000                 CA           100
# ...      ...             ...            ...                ...           ...
# 1780  134500             USD         134500                 US             0
# 1781  130000             USD         130000                 US             0
# 1782   90000             USD          90000                 US             0
# 1783  160000             USD         160000                 US             0
# 1784  135000             USD         135000                 US             0
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 1780               US            L
# 1781               US            M
# 1782               US            M
# 1783               US            M
# 1784               US            M
#
# [1785 rows x 11 columns]

# %% [markdown]
# 14. Find all records where the salary_currency is USD.

# %%
query = "SELECT * FROM salary WHERE salary_currency = 'USD'"
usd_salaries = pd.read_sql_query(query, connection)
usd_salaries
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              CT               ML Engineer
# 1          2023               MI              CT               ML Engineer
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT         Applied Scientist
# ...         ...              ...             ...                       ...
# 3219       2021               SE              FT           Data Specialist
# 3220       2020               SE              FT            Data Scientist
# 3221       2021               MI              FT  Principal Data Scientist
# 3222       2020               EN              FT            Data Scientist
# 3223       2020               EN              CT     Business Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      30000             USD          30000                 US           100
# 1      25500             USD          25500                 US           100
# 2     175000             USD         175000                 CA           100
# 3     120000             USD         120000                 CA           100
# 4     222200             USD         222200                 US             0
# ...      ...             ...            ...                ...           ...
# 3219  165000             USD         165000                 US           100
# 3220  412000             USD         412000                 US           100
# 3221  151000             USD         151000                 US           100
# 3222  105000             USD         105000                 US           100
# 3223  100000             USD         100000                 US           100
#
#      company_location company_size
# 0                  US            S
# 1                  US            S
# 2                  CA            M
# 3                  CA            M
# 4                  US            L
# ...               ...          ...
# 3219               US            L
# 3220               US            L
# 3221               US            L
# 3222               US            S
# 3223               US            L
#
# [3224 rows x 11 columns]

# %% [markdown]
# 15. Filter records for employees whose salary_in_usd is
# greater than the average salary.

# %%
cursor = connection.cursor()
cursor

# %%
cursor.execute("SELECT AVG(salary_in_usd) FROM salary")
cursor.fetchall()
# Out:
# [(137570.38988015978,)]

# %%
query = "SELECT * FROM salary WHERE salary_in_usd > (SELECT AVG(salary_in_usd) FROM salary)"
above_avg_salaries = pd.read_sql_query(query, connection)
above_avg_salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               SE              FT
# 2          2023               SE              FT
# 3          2023               SE              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 1794       2021               SE              FT
# 1795       2021               MI              FT
# 1796       2021               SE              FT
# 1797       2020               SE              FT
# 1798       2021               MI              FT
#
#                                job_title  salary salary_currency  \
# 0                         Data Scientist  175000             USD
# 1                      Applied Scientist  222200             USD
# 2                         Data Scientist  219000             USD
# 3                         Data Scientist  141000             USD
# 4                         Data Scientist  147100             USD
# ...                                  ...     ...             ...
# 1794            Director of Data Science  168000             USD
# 1795  Applied Machine Learning Scientist  423000             USD
# 1796                     Data Specialist  165000             USD
# 1797                      Data Scientist  412000             USD
# 1798            Principal Data Scientist  151000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0            175000                 CA           100               CA
# 1            222200                 US             0               US
# 2            219000                 CA             0               CA
# 3            141000                 CA             0               CA
# 4            147100                 US             0               US
# ...             ...                ...           ...              ...
# 1794         168000                 JP             0               JP
# 1795         423000                 US            50               US
# 1796         165000                 US           100               US
# 1797         412000                 US           100               US
# 1798         151000                 US           100               US
#
#      company_size
# 0               M
# 1               L
# 2               M
# 3               M
# 4               M
# ...           ...
# 1794            S
# 1795            L
# 1796            L
# 1797            L
# 1798            L
#
# [1799 rows x 11 columns]

# %% [markdown]
# ## Sorting with ORDER BY

# %% [markdown]
# 16. Fetch all employees, sorted by their salary_in_usd in
# descending order.

# %%
query = "SELECT * FROM salary ORDER BY salary_in_usd DESC"
sorted_employees = pd.read_sql_query(query, connection)
sorted_employees
# Out:
#       work_year experience_level employment_type  \
# 0          2020               MI              FT
# 1          2022               MI              FT
# 2          2023               SE              FT
# 3          2021               MI              FT
# 4          2021               EX              CT
# ...         ...              ...             ...
# 3750       2020               EN              FT
# 3751       2021               MI              FT
# 3752       2021               EN              FT
# 3753       2021               MI              PT
# 3754       2022               MI              FT
#
#                                job_title   salary salary_currency  \
# 0                     Research Scientist   450000             USD
# 1                           Data Analyst   350000             GBP
# 2                           AI Scientist  1500000             ILS
# 3     Applied Machine Learning Scientist   423000             USD
# 4               Principal Data Scientist   416000             USD
# ...                                  ...      ...             ...
# 3750             Data Science Consultant   423000             INR
# 3751                      Data Scientist   420000             INR
# 3752                  Power BI Developer   400000             INR
# 3753       3D Computer Vision Researcher   400000             INR
# 3754                        NLP Engineer   120000             CZK
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0            450000                 US             0               US
# 1            430967                 GB             0               GB
# 2            423834                 IL             0               IL
# 3            423000                 US            50               US
# 4            416000                 US           100               US
# ...             ...                ...           ...              ...
# 3750           5707                 IN            50               IN
# 3751           5679                 IN           100               US
# 3752           5409                 IN            50               IN
# 3753           5409                 IN            50               IN
# 3754           5132                 CZ           100               CZ
#
#      company_size
# 0               M
# 1               M
# 2               L
# 3               L
# 4               S
# ...           ...
# 3750            M
# 3751            S
# 3752            L
# 3753            M
# 3754            M
#
# [3755 rows x 11 columns]

# %% [markdown]
# 17. Retrieve employees sorted by job_title and then by
# salary_in_usd.

# %%
query = "SELECT * FROM salary ORDER BY job_title ASC, salary_in_usd ASC"
sorted_employees = pd.read_sql_query(query, connection)
sorted_employees
# Out:
#       work_year experience_level employment_type  \
# 0          2021               MI              PT
# 1          2022               SE              FT
# 2          2021               EN              FT
# 3          2022               EN              FT
# 4          2022               EN              FT
# ...         ...              ...             ...
# 3750       2020               MI              FT
# 3751       2023               SE              FL
# 3752       2023               MI              FT
# 3753       2020               EX              FT
# 3754       2021               SE              CT
#
#                           job_title  salary salary_currency  salary_in_usd  \
# 0     3D Computer Vision Researcher  400000             INR           5409
# 1     3D Computer Vision Researcher   10000             USD          10000
# 2     3D Computer Vision Researcher   20000             USD          20000
# 3     3D Computer Vision Researcher   50000             USD          50000
# 4                      AI Developer    6000             EUR           6304
# ...                             ...     ...             ...            ...
# 3750             Research Scientist  450000             USD         450000
# 3751         Software Data Engineer   50000             USD          50000
# 3752         Software Data Engineer  100000             SGD          75020
# 3753             Staff Data Analyst   15000             USD          15000
# 3754           Staff Data Scientist  105000             USD         105000
#
#      employee_residence  remote_ratio company_location company_size
# 0                    IN            50               IN            M
# 1                    CA            50               AL            S
# 2                    AS             0               AS            M
# 3                    US           100               CR            S
# 4                    MK             0               MK            S
# ...                 ...           ...              ...          ...
# 3750                 US             0               US            M
# 3751                 NG            50               AU            M
# 3752                 SG           100               SG            L
# 3753                 NG             0               CA            M
# 3754                 US           100               US            M
#
# [3755 rows x 11 columns]

# %% [markdown]
# 18. Sort all employees based on their remote_ratio in
# ascending order.

# %%
query = "SELECT * FROM salary ORDER BY remote_ratio ASC"
remote_ratio = pd.read_sql_query(query, connection)
remote_ratio
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT         Applied Scientist
# 1          2023               SE              FT         Applied Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2021               SE              FT           Data Specialist
# 3751       2020               SE              FT            Data Scientist
# 3752       2021               MI              FT  Principal Data Scientist
# 3753       2020               EN              FT            Data Scientist
# 3754       2020               EN              CT     Business Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     222200             USD         222200                 US             0
# 1     136000             USD         136000                 US             0
# 2     219000             USD         219000                 CA             0
# 3     141000             USD         141000                 CA             0
# 4     147100             USD         147100                 US             0
# ...      ...             ...            ...                ...           ...
# 3750  165000             USD         165000                 US           100
# 3751  412000             USD         412000                 US           100
# 3752  151000             USD         151000                 US           100
# 3753  105000             USD         105000                 US           100
# 3754  100000             USD         100000                 US           100
#
#      company_location company_size
# 0                  US            L
# 1                  US            L
# 2                  CA            M
# 3                  CA            M
# 4                  US            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            L
# 3753               US            S
# 3754               US            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# 19. Display the employees ordered by company_size and
# then by experience_level.

# %%
query = "SELECT * FROM salary ORDER BY company_size ASC, experience_level ASC"
sorted_by_company_and_experience= pd.read_sql_query(query, connection)
sorted_by_company_and_experience
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3750       2021               SE              FT              Data Engineer
# 3751       2020               SE              FL   Computer Vision Engineer
# 3752       2020               SE              FT             Data Scientist
# 3753       2020               SE              FT  Machine Learning Engineer
# 3754       2021               SE              FT   Director of Data Science
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     213660             USD         213660                 US             0
# 1     130760             USD         130760                 US             0
# 2     100000             USD         100000                 NG           100
# 3      30000             USD          30000                 NG           100
# 4     204620             USD         204620                 US             0
# ...      ...             ...            ...                ...           ...
# 3750   65000             EUR          76833                 RO            50
# 3751   60000             USD          60000                 RU           100
# 3752   80000             EUR          91237                 AT             0
# 3753   40000             EUR          45618                 HR           100
# 3754  168000             USD         168000                 JP             0
#
#      company_location company_size
# 0                  US            L
# 1                  US            L
# 2                  NG            L
# 3                  NG            L
# 4                  US            L
# ...               ...          ...
# 3750               GB            S
# 3751               US            S
# 3752               AT            S
# 3753               HR            S
# 3754               JP            S
#
# [3755 rows x 11 columns]

# %% [markdown]
# 20. List all employees sorted by work_year in descending
# order.

# %%
query = "SELECT * FROM salary ORDER BY work_year DESC"
work_year = pd.read_sql_query(query, connection)
work_year
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 3750       2020               MI              FT              Data Engineer
# 3751       2020               SE              FT  Machine Learning Engineer
# 3752       2020               SE              FT             Data Scientist
# 3753       2020               EN              FT             Data Scientist
# 3754       2020               EN              CT      Business Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      80000             EUR          85847                 ES           100
# 1      30000             USD          30000                 US           100
# 2      25500             USD          25500                 US           100
# 3     175000             USD         175000                 CA           100
# 4     120000             USD         120000                 CA           100
# ...      ...             ...            ...                ...           ...
# 3750  130800             USD         130800                 ES           100
# 3751   40000             EUR          45618                 HR           100
# 3752  412000             USD         412000                 US           100
# 3753  105000             USD         105000                 US           100
# 3754  100000             USD         100000                 US           100
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            M
# 3751               HR            S
# 3752               US            L
# 3753               US            S
# 3754               US            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# ## Limiting Results

# %% [markdown]
# 21. Fetch the top 5 highest-paid employees.

# %%
query = "SELECT * FROM salary ORDER BY salary_in_usd DESC LIMIT 5"
top_5_highest_paid = pd.read_sql_query(query, connection)
top_5_highest_paid
# Out:
#    work_year experience_level employment_type  \
# 0       2020               MI              FT
# 1       2022               MI              FT
# 2       2023               SE              FT
# 3       2021               MI              FT
# 4       2021               EX              CT
#
#                             job_title   salary salary_currency  salary_in_usd  \
# 0                  Research Scientist   450000             USD         450000
# 1                        Data Analyst   350000             GBP         430967
# 2                        AI Scientist  1500000             ILS         423834
# 3  Applied Machine Learning Scientist   423000             USD         423000
# 4            Principal Data Scientist   416000             USD         416000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US             0               US            M
# 1                 GB             0               GB            M
# 2                 IL             0               IL            L
# 3                 US            50               US            L
# 4                 US           100               US            S

# %% [markdown]
# 22. Retrieve the first 10 records from the dataset

# %%
query = "SELECT * FROM salary LIMIT 10"
first_10_records = pd.read_sql_query(query, connection)
first_10_records
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
# 6       2023               SE              FT         Applied Scientist
# 7       2023               SE              FT            Data Scientist
# 8       2023               SE              FT            Data Scientist
# 9       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
# 5  222200             USD         222200                 US             0
# 6  136000             USD         136000                 US             0
# 7  219000             USD         219000                 CA             0
# 8  141000             USD         141000                 CA             0
# 9  147100             USD         147100                 US             0
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M
# 5               US            L
# 6               US            L
# 7               CA            M
# 8               CA            M
# 9               US            M

# %% [markdown]
# 23. Show the last 5 rows of the dataset (Hint: Use OFFSET
# with LIMIT)

# %% [markdown]
# 24. Fetch the top 3 employees with the lowest salaries.

# %%
query = """SELECT * FROM salary ORDER BY salary_in_usd ASC LIMIT 3"""
lowest_3_salaries = pd.read_sql_query(query, connection)
lowest_3_salaries
# Out:
#    work_year experience_level employment_type                      job_title  \
# 0       2022               MI              FT                   NLP Engineer
# 1       2021               EN              FT             Power BI Developer
# 2       2021               MI              PT  3D Computer Vision Researcher
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  120000             CZK           5132                 CZ           100
# 1  400000             INR           5409                 IN            50
# 2  400000             INR           5409                 IN            50
#
#   company_location company_size
# 0               CZ            M
# 1               IN            L
# 2               IN            M

# %% [markdown]
# 25. Display 5 records from the dataset starting from the
# 11th record.

# %% [markdown]
# ## Aggregations

# %% [markdown]
# 26. Find the total number of employees.

# %%
cursor.execute("SELECT COUNT(*) AS total_employees FROM salary")
cursor.fetchall()
# Out:
# [(3755,)]

# %% [markdown]
# 27. Calculate the average salary in USD.

# %%
cursor.execute("SELECT AVG(salary_in_usd) FROM salary")
cursor.fetchall()
# Out:
# [(137570.38988015978,)]

# %% [markdown]
# 28. Find the maximum and minimum salary in USD.

# %%
cursor.execute("SELECT MAX(salary_in_usd),MIN(salary_in_usd) FROM salary")
cursor.fetchall()
# Out:
# [(450000, 5132)]

# %% [markdown]
# 29. Count the number of employees grouped by their
# experience_level.

# %%
query = "SELECT experience_level, COUNT(*) AS employee_count FROM salary GROUP BY experience_level"
experience_level_counts = pd.read_sql_query(query, connection)
experience_level_counts
# Out:
#   experience_level  employee_count
# 0               EN             320
# 1               EX             114
# 2               MI             805
# 3               SE            2516

# %%
cursor.execute("SELECT experience_level, COUNT(*) FROM salary GROUP BY experience_level")
cursor.fetchall()
# Out:
# [('EN', 320), ('EX', 114), ('MI', 805), ('SE', 2516)]

# %% [markdown]
# 30. Calculate the total salary paid to employees in Canada
# (employee_residence = 'CA').

# %%
cursor.execute("SELECT SUM(salary_in_usd) FROM salary WHERE employee_residence = 'CA'")
cursor.fetchall()
# Out:
# [(11238947,)]

# %% [markdown]
# 31. Find the average salary for employees with
# remote_ratio = 100.

# %%
cursor.execute("SELECT AVG(salary_in_usd) FROM salary WHERE remote_ratio = 100")
cursor.fetchall()
# Out:
# [(136481.45283018867,)]

# %% [markdown]
# 32. Count how many employees are working in mediumsized companies.

# %%
cursor.execute("SELECT COUNT(*) FROM salary WHERE company_size = 'M'")
cursor.fetchall()
# Out:
# [(3153,)]

# %% [markdown]
# 33. Find the sum of salaries for employees with the title
# "ML Engineer"

# %%
cursor.execute("SELECT SUM(salary_in_usd) FROM salary WHERE job_title = 'ML Engineer'")
cursor.fetchall()
# Out:
# [(5383983,)]

# %% [markdown]
# 34. Determine the maximum salary for each
# experience_level.

# %%
cursor.execute("SELECT MAX(salary_in_usd) FROM salary GROUP BY experience_level")
cursor.fetchall()
# Out:
# [(300000,), (416000,), (450000,), (423834,)]

# %%
query = "SELECT experience_level, MAX(salary_in_usd) FROM salary GROUP BY experience_level"""
max_salary_per_experience = pd.read_sql_query(query, connection)
max_salary_per_experience
# Out:
#   experience_level  MAX(salary_in_usd)
# 0               EN              300000
# 1               EX              416000
# 2               MI              450000
# 3               SE              423834

# %% [markdown]
# 35. Calculate the average salary for each
# employment_type.

# %%
query = "SELECT employment_type, AVG(salary_in_usd) FROM salary GROUP BY employment_type"
avg_salary = pd.read_sql_query(query, connection)
avg_salary
# Out:
#   employment_type  AVG(salary_in_usd)
# 0              CT       113446.900000
# 1              FL        51807.800000
# 2              FT       138314.199570
# 3              PT        39533.705882

# %% [markdown]
# ## Group By

# %% [markdown]
# 36. Group the data by job_title and count the number of
# employees in each role.

# %%
query = "SELECT job_title, COUNT(*) AS employee_count FROM salary GROUP BY job_title ORDER BY COUNT(*) DESC"
employee_count_role = pd.read_sql_query(query, connection)
employee_count_role
# Out:
#                     job_title  employee_count
# 0               Data Engineer            1040
# 1              Data Scientist             840
# 2                Data Analyst             612
# 3   Machine Learning Engineer             289
# 4          Analytics Engineer             103
# ..                        ...             ...
# 88       Data DevOps Engineer               1
# 89    Compliance Data Analyst               1
# 90       Cloud Data Architect               1
# 91           BI Data Engineer               1
# 92        Azure Data Engineer               1
#
# [93 rows x 2 columns]

# %% [markdown]
# 37. Find the total salary for each company_location.

# %%
query = "SELECT company_location, SUM(salary_in_usd) AS total_salary FROM salary GROUP BY company_location ORDER BY total_salary DESC"
total_salary_by_location = pd.read_sql_query(query, connection)
total_salary_by_location
# Out:
#    company_location  total_salary
# 0                US     461538909
# 1                GB      14945089
# 2                CA      11476839
# 3                DE       4944173
# 4                ES       4441057
# ..              ...           ...
# 67               VN         12000
# 68               MA         10000
# 69               AL         10000
# 70               BO          7500
# 71               MK          6304
#
# [72 rows x 2 columns]

# %% [markdown]
# 38. Group the employees by work_year and calculate the
# average salary in USD.

# %%
query = "SELECT work_year, AVG(salary_in_usd) FROM salary GROUP BY work_year ORDER BY work_year ASC"
avg_salary_by_work_year = pd.read_sql_query(query, connection)
avg_salary_by_work_year
# Out:
#    work_year  AVG(salary_in_usd)
# 0       2020        92302.631579
# 1       2021        94087.208696
# 2       2022       133338.620793
# 3       2023       149045.541176

# %% [markdown]
# 39. Count the number of employees grouped by
# remote_ratio.

# %%
query = "SELECT remote_ratio, COUNT(*) FROM salary GROUP BY remote_ratio ORDER BY remote_ratio ASC"
employee_count_by_remote_ratio = pd.read_sql_query(query, connection)
employee_count_by_remote_ratio
# Out:
#    remote_ratio  COUNT(*)
# 0             0      1923
# 1            50       189
# 2           100      1643

# %% [markdown]
# 40. Find the average salary_in_usd for employees
# grouped by salary_currency.

# %%
query = "SELECT salary_currency, AVG(salary_in_usd) AS avg_salary FROM salary GROUP BY salary_currency ORDER BY avg_salary DESC"
avg_salary_by_currency = pd.read_sql_query(query, connection)
avg_salary_by_currency
# Out:
#    salary_currency     avg_salary
# 0              ILS  423834.000000
# 1              USD  149366.906638
# 2              CHF  100682.000000
# 3              CAD   96707.400000
# 4              GBP   83850.229814
# 5              SGD   81770.000000
# 6              AUD   74198.444444
# 7              HKD   65062.000000
# 8              EUR   62281.733051
# 9              JPY   60921.333333
# 10             CLP   40038.000000
# 11             PLN   34165.200000
# 12             MXN   33511.000000
# 13             DKK   31192.666667
# 14             HUF   29892.666667
# 15             THB   27096.500000
# 16             INR   25785.300000
# 17             TRY   20096.666667
# 18             BRL   12448.000000
# 19             CZK    5132.000000

# %% [markdown]
# ## Joins
# 41. Create a second table with department information
# and perform an inner join to show job titles with their
# department

# %%
department_data = {
    'job_title': ['Data Scientist', 'ML Engineer', 'Data Engineer', 'Software Engineer'],
    'department': ['Data Analytics', 'AI/ML Research', 'Data Engineering', 'Development']
}
department_df = pd.DataFrame(department_data)
department_df.to_sql("department", connection, if_exists="replace", index=False)
pd.read_sql_query("SELECT * FROM department", connection)
# Out:
#            job_title        department
# 0     Data Scientist    Data Analytics
# 1        ML Engineer    AI/ML Research
# 2      Data Engineer  Data Engineering
# 3  Software Engineer       Development

# %% [markdown]
# 42. Perform a left join to display all employees, even if they
# don’t have department data.

# %%
query = "SELECT salary.job_title, department.department FROM salary LEFT JOIN department ON salary.job_title = department.job_title"
all_employees_with_departments = pd.read_sql_query(query, connection)
all_employees_with_departments
# Out:
#                      job_title      department
# 0     Principal Data Scientist            None
# 1                  ML Engineer  AI/ML Research
# 2                  ML Engineer  AI/ML Research
# 3               Data Scientist  Data Analytics
# 4               Data Scientist  Data Analytics
# ...                        ...             ...
# 3750            Data Scientist  Data Analytics
# 3751  Principal Data Scientist            None
# 3752            Data Scientist  Data Analytics
# 3753     Business Data Analyst            None
# 3754      Data Science Manager            None
#
# [3755 rows x 2 columns]

# %% [markdown]
# 43. Use a right join to fetch all department data, even if no
# employees are linked.

# %%
query = "SELECT department.job_title, department.department, salary.job_title AS employee_job_title FROM department LEFT JOIN salary ON department.job_title = salary.job_title"
all_departments_with_employees = pd.read_sql_query(query, connection)
all_departments_with_employees
# Out:
#               job_title        department employee_job_title
# 0        Data Scientist    Data Analytics     Data Scientist
# 1        Data Scientist    Data Analytics     Data Scientist
# 2        Data Scientist    Data Analytics     Data Scientist
# 3        Data Scientist    Data Analytics     Data Scientist
# 4        Data Scientist    Data Analytics     Data Scientist
# ...                 ...               ...                ...
# 1910      Data Engineer  Data Engineering      Data Engineer
# 1911      Data Engineer  Data Engineering      Data Engineer
# 1912      Data Engineer  Data Engineering      Data Engineer
# 1913      Data Engineer  Data Engineering      Data Engineer
# 1914  Software Engineer       Development               None
#
# [1915 rows x 3 columns]

# %%
query = "SELECT department.job_title, department.department, salary.job_title AS employee_job_title FROM department RIGHT JOIN salary ON department.job_title = salary.job_title"
all_departments_with_employees = pd.read_sql_query(query, connection)
all_departments_with_employees
# Out:
#            job_title      department                  employee_job_title
# 0     Data Scientist  Data Analytics                      Data Scientist
# 1     Data Scientist  Data Analytics                      Data Scientist
# 2     Data Scientist  Data Analytics                      Data Scientist
# 3     Data Scientist  Data Analytics                      Data Scientist
# 4     Data Scientist  Data Analytics                      Data Scientist
# ...              ...             ...                                 ...
# 3750            None            None  Applied Machine Learning Scientist
# 3751            None            None                     Data Specialist
# 3752            None            None            Principal Data Scientist
# 3753            None            None               Business Data Analyst
# 3754            None            None                Data Science Manager
#
# [3755 rows x 3 columns]

# %% [markdown]
# 44. Create a new table for job categories and perform a full
# outer join to combine it with the dataset.

# %%
job_categories_data = {
    'job_title': ['Data Scientist', 'ML Engineer', 'Data Engineer', 'Business Analyst'],
    'job_category': ['Data Analytics', 'AI/ML Research', 'Engineering', 'Business']
}
job_categories_df = pd.DataFrame(job_categories_data)
job_categories_df.to_sql("job_categories", connection, if_exists="replace", index=False)
pd.read_sql_query("SELECT * FROM job_categories", connection)
# Out:
#           job_title    job_category
# 0    Data Scientist  Data Analytics
# 1       ML Engineer  AI/ML Research
# 2     Data Engineer     Engineering
# 3  Business Analyst        Business

# %%
query1 = "SELECT salary.job_title, salary.salary_in_usd, job_categories.job_category FROM salary LEFT JOIN job_categories ON salary.job_title = job_categories.job_title" 
pd.read_sql_query(query1, connection)
# Out:
#                      job_title  salary_in_usd    job_category
# 0     Principal Data Scientist          85847            None
# 1                  ML Engineer          30000  AI/ML Research
# 2                  ML Engineer          25500  AI/ML Research
# 3               Data Scientist         175000  Data Analytics
# 4               Data Scientist         120000  Data Analytics
# ...                        ...            ...             ...
# 3750            Data Scientist         412000  Data Analytics
# 3751  Principal Data Scientist         151000            None
# 3752            Data Scientist         105000  Data Analytics
# 3753     Business Data Analyst         100000            None
# 3754      Data Science Manager          94665            None
#
# [3755 rows x 3 columns]

# %%
query2="SELECT salary.job_title, salary.salary_in_usd, job_categories.job_category FROM job_categories LEFT JOIN salary ON salary.job_title = job_categories.job_title"
pd.read_sql_query(query2, connection)
# Out:
#            job_title  salary_in_usd    job_category
# 0     Data Scientist         5679.0  Data Analytics
# 1     Data Scientist         9466.0  Data Analytics
# 2     Data Scientist         9727.0  Data Analytics
# 3     Data Scientist        10000.0  Data Analytics
# 4     Data Scientist        12767.0  Data Analytics
# ...              ...            ...             ...
# 1910   Data Engineer       310000.0     Engineering
# 1911   Data Engineer       310000.0     Engineering
# 1912   Data Engineer       315000.0     Engineering
# 1913   Data Engineer       324000.0     Engineering
# 1914            None            NaN        Business
#
# [1915 rows x 3 columns]

# %%
query=f"{query1} UNION {query2}"
pd.read_sql_query(query, connection)
# Out:
#                           job_title  salary_in_usd job_category
# 0                              None            NaN     Business
# 1     3D Computer Vision Researcher         5409.0         None
# 2     3D Computer Vision Researcher        10000.0         None
# 3     3D Computer Vision Researcher        20000.0         None
# 4     3D Computer Vision Researcher        50000.0         None
# ...                             ...            ...          ...
# 1835             Research Scientist       450000.0         None
# 1836         Software Data Engineer        50000.0         None
# 1837         Software Data Engineer        75020.0         None
# 1838             Staff Data Analyst        15000.0         None
# 1839           Staff Data Scientist       105000.0         None
#
# [1840 rows x 3 columns]

# %% [markdown]
# 45. Perform a self-join on the dataset to find employees
# with the same salary_in_usd.

# %% [markdown]
# ## Subqueries
# 46. Find employees whose salary is greater than the
# average salary of all employees.

# %%
query = "SELECT * FROM salary WHERE salary_in_usd > (SELECT AVG(salary_in_usd) FROM salary)"
above_average_salary = pd.read_sql_query(query, connection)
above_average_salary
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               SE              FT
# 2          2023               SE              FT
# 3          2023               SE              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 1794       2021               SE              FT
# 1795       2021               MI              FT
# 1796       2021               SE              FT
# 1797       2020               SE              FT
# 1798       2021               MI              FT
#
#                                job_title  salary salary_currency  \
# 0                         Data Scientist  175000             USD
# 1                      Applied Scientist  222200             USD
# 2                         Data Scientist  219000             USD
# 3                         Data Scientist  141000             USD
# 4                         Data Scientist  147100             USD
# ...                                  ...     ...             ...
# 1794            Director of Data Science  168000             USD
# 1795  Applied Machine Learning Scientist  423000             USD
# 1796                     Data Specialist  165000             USD
# 1797                      Data Scientist  412000             USD
# 1798            Principal Data Scientist  151000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0            175000                 CA           100               CA
# 1            222200                 US             0               US
# 2            219000                 CA             0               CA
# 3            141000                 CA             0               CA
# 4            147100                 US             0               US
# ...             ...                ...           ...              ...
# 1794         168000                 JP             0               JP
# 1795         423000                 US            50               US
# 1796         165000                 US           100               US
# 1797         412000                 US           100               US
# 1798         151000                 US           100               US
#
#      company_size
# 0               M
# 1               L
# 2               M
# 3               M
# 4               M
# ...           ...
# 1794            S
# 1795            L
# 1796            L
# 1797            L
# 1798            L
#
# [1799 rows x 11 columns]

# %% [markdown]
# 47. Display job titles with salaries greater than the
# maximum salary of employees in Canada.

# %%
query = "SELECT job_title, salary_in_usd FROM salary WHERE salary_in_usd > (SELECT MAX(salary_in_usd) FROM salary WHERE employee_residence = 'CA')"
salaries_max_in_ca = pd.read_sql_query(query, connection)
salaries_max_in_ca
# Out:
#                              job_title  salary_in_usd
# 0             Computer Vision Engineer         342810
# 1                       Data Scientist         275300
# 2                    Applied Scientist         309400
# 3             Computer Vision Engineer         280000
# 4                       Data Architect         280100
# ..                                 ...            ...
# 87                  Lead Data Engineer         276000
# 88            Principal Data Scientist         416000
# 89            Director of Data Science         325000
# 90  Applied Machine Learning Scientist         423000
# 91                      Data Scientist         412000
#
# [92 rows x 2 columns]

# %% [markdown]
# 48. Fetch all records where salary_in_usd is equal to the
# minimum salary of employees in US.

# %%
query = "SELECT * FROM salary WHERE salary_in_usd = (SELECT MIN(salary_in_usd) FROM salary WHERE employee_residence = 'US')"
min_salary_us = pd.read_sql_query(query, connection)
min_salary_us
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2022               MI              FT             Data Engineer
# 1       2022               MI              FT             Data Engineer
# 2       2021               SE              FT  Computer Vision Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   24000             USD          24000                 US             0
# 1   24000             USD          24000                 US             0
# 2   24000             USD          24000                 BR           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               BR            M

# %% [markdown]
# 49. List all employees with a remote_ratio greater than
# the average remote_ratio of all employees.

# %%
query = "SELECT * FROM salary WHERE remote_ratio > (SELECT AVG(remote_ratio) FROM salary)"
above_average_remote_ratio = pd.read_sql_query(query, connection)
above_average_remote_ratio
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 1827       2020               SE              FT            Data Scientist
# 1828       2021               MI              FT  Principal Data Scientist
# 1829       2020               EN              FT            Data Scientist
# 1830       2020               EN              CT     Business Data Analyst
# 1831       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 1827   412000             USD         412000                 US           100
# 1828   151000             USD         151000                 US           100
# 1829   105000             USD         105000                 US           100
# 1830   100000             USD         100000                 US           100
# 1831  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 1827               US            L
# 1828               US            L
# 1829               US            S
# 1830               US            L
# 1831               IN            L
#
# [1832 rows x 11 columns]

# %% [markdown]
# 50. Count the number of employees who earn more than
# the highest-paid employee in a small-sized company
# (company_size = 'S')

# %%
cursor.execute("SELECT COUNT(*) FROM salary WHERE salary_in_usd > (SELECT MAX(salary_in_usd) FROM salary WHERE company_size = 'S')")
cursor.fetchall()
# Out:
# [(4,)]
